# %%
import os
dir = "/Users/canglong/Movies/原神旋律素材/视频"
for root, dirs, files in os.walk(dir):
    for file in files:
        file = os.path.splitext(file)[0]
        print(f"ffmpeg -i {file}.flv -vcodec copy -acodec copy {file}.mp4\n")
        # print(file)
# Out:
# ffmpeg -i 《原神》全新角色演示-「七七_冰寒流转」.七七.231875355.flv -vcodec copy -acodec copy 《原神》全新角色演示-「七七_冰寒流转」.七七.231875355.mp4
#
# ffmpeg -i 《原神》全新角色演示-「罗莎莉亚_绝不加班」.《原神》全新角色演示-「罗莎莉亚_绝不加班」.316848436.flv -vcodec copy -acodec copy 《原神》全新角色演示-「罗莎莉亚_绝不加班」.《原神》全新角色演示-「罗莎莉亚_绝不加班」.316848436.mp4
#
# ffmpeg -i TGA2021《原神》参选视频.TGA2021《原神》参选视频.458365117.flv -vcodec copy -acodec copy TGA2021《原神》参选视频.TGA2021《原神》参选视频.458365117.mp4
#
# ffmpeg -i 《原神》角色演示-「枫原万叶_风流蕴藉」.《原神》角色演示-「枫原万叶_风流蕴藉」.359577041.flv -vcodec copy -acodec copy 《原神》角色演示-「枫原万叶_风流蕴藉」.《原神》角色演示-「枫原万叶_风流蕴藉」.359577041.mp4
#
# ffmpeg -i 《原神》角色演示-「优菈_闪灼的烛光」.《原神》角色演示-「优菈_闪灼的烛光」.338437607.flv -vcodec copy -acodec copy 《原神》角色演示-「优菈_闪灼的烛光」.《原神》角色演示-「优菈_闪灼的烛光」.338437607.mp4
#
# ffmpeg -i .DS_Store.flv -vcodec copy -acodec copy .DS_Store.mp4
#
# ffmpeg -i 《原神》全新角色演示-「迪奥娜_酒业杀手」.《原神》全新角色演示-「迪奥娜_酒业杀手」.253559288.flv -vcodec copy -acodec copy 《原神》全新角色演示-「迪奥娜_酒业杀手」.《原神》全新角色演示-「迪奥娜_酒业杀手」.253559288.mp4
#
# ...
